# %%
#Pset8 Aaron McGarvey
#Worked with Spencer Harris for Pandas tutorial

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
pd.set_option('max_rows',15) # this limit maximum numbers of rows
np.set_printoptions(precision=3 , suppress= True) # this is just to make the output look better

# %%
pd.__version__
# Out:
# '0.20.1'

# %%
more ./DelhiTmax.txt

# %%
tmax = pd.read_csv('./DelhiTmax.txt',delimiter=r"\s+", parse_dates=[[0,1,2]], header=None)

# %%
tmax
# Out:
#            0_1_2     3
# 0     1944-01-01  22.2
# 1     1944-01-03  23.9
# 2     1944-01-04  22.2
# 3     1944-01-06  22.8
# 4     1944-01-07  22.2
# 5     1944-01-08  16.7
# 6     1944-01-09  20.6
# ...          ...   ...
# 15429 2015-02-22  28.6
# 15430 2015-02-23  28.6
# 15431 2015-02-24  28.6
# 15432 2015-02-25  28.6
# 15433 2015-02-26  27.6
# 15434 2015-02-27  27.6
# 15435 2015-02-28  29.2
#
# [15436 rows x 2 columns]

# %%
tmax.columns = ['Date', 'Temp']

# %%
tmax = tmax.set_index(['Date'])

# %%
tmax.head(3)
# Out:
#             Temp
# Date
# 1944-01-01  22.2
# 1944-01-03  23.9
# 1944-01-04  22.2

# %%
tmax.plot()

# %%
tmax['1980':'1990'].plot()

# %%
tmax['1980-05':'1980-07'].plot()

# %%
tmax['1980-01-02':'1980-01-02']
# Out:
#             Temp
# Date
# 1980-01-02  16.0

# %%
tmax.iloc[120]
# Out:
# Temp    35.0
# Name: 1944-06-17 00:00:00, dtype: float64

# %%
tmax['1980-01'].plot()

# %% [markdown]
# What was temperature in Delhi at your burthsday (or at the closest day)?

# %%
tmax['1988-07-29':'1988-07-29']
# Out:
#             Temp
# Date
# 1988-07-29  34.8

# %%
tmax[tmax > 30].plot(style='r*')

# %% [markdown]
# plot all temperatures larger than 10 (red stars) and temperatires lower than 10 (blue stars) limit this plot by 1990-2013 period

# %%
x = tmax['1990-01-01':'2013-01-01']

# %%
y = (tmax[tmax>10])
z = (tmax[tmax<10])
fig, ax = plt.subplots()

ax.plot(y, 'r*')
ax.plot(z, 'b*')
plt.xlim(('1990','2013'))
# Out:
# (726468.0, 734869.0)

# %% [markdown]
# Multiple columns
# Now let's make live a bit more interesting and get more data. This will be TMIN time series.

# %%
tmin = pd.read_csv('./DelhiTmin.txt',delimiter=r"\s+", parse_dates=[[0,1,2]], header=None)
tmin.columns = ['Date', 'Temp']
tmin = tmin.set_index(['Date'])

# %%
tmin.plot()

# %%
tmin.describe()
# Out:
#                Temp
# count  14208.000000
# mean      18.530961
# std        7.808766
# min        0.000000
# 25%       11.400000
# 50%       19.500000
# 75%       25.600000
# max       36.400000

# %%
tmax.describe()
# Out:
#                Temp
# count  15436.000000
# mean      31.402131
# std        6.740111
# min        9.800000
# 25%       26.200000
# 50%       32.600000
# 75%       36.100000
# max       47.900000

# %%
dd = pd.date_range('1944-01','2015-03',freq='D')

# %%
dd
# Out:
# DatetimeIndex(['1944-01-01', '1944-01-02', '1944-01-03', '1944-01-04',
#                '1944-01-05', '1944-01-06', '1944-01-07', '1944-01-08',
#                '1944-01-09', '1944-01-10',
#                ...
#                '2015-02-20', '2015-02-21', '2015-02-22', '2015-02-23',
#                '2015-02-24', '2015-02-25', '2015-02-26', '2015-02-27',
#                '2015-02-28', '2015-03-01'],
#               dtype='datetime64[ns]', length=25993, freq='D')

# %%
tmp = pd.DataFrame(index=dd)

# %%
tmp
# Out:
# Empty DataFrame
# Columns: []
# Index: [1944-01-01 00:00:00, 1944-01-02 00:00:00, 1944-01-03 00:00:00, 1944-01-04 00:00:00, 1944-01-05 00:00:00, 1944-01-06 00:00:00, 1944-01-07 00:00:00, 1944-01-08 00:00:00, 1944-01-09 00:00:00, 1944-01-10 00:00:00, 1944-01-11 00:00:00, 1944-01-12 00:00:00, 1944-01-13 00:00:00, 1944-01-14 00:00:00, 1944-01-15 00:00:00, 1944-01-16 00:00:00, 1944-01-17 00:00:00, 1944-01-18 00:00:00, 1944-01-19 00:00:00, 1944-01-20 00:00:00, 1944-01-21 00:00:00, 1944-01-22 00:00:00, 1944-01-23 00:00:00, 1944-01-24 00:00:00, 1944-01-25 00:00:00, 1944-01-26 00:00:00, 1944-01-27 00:00:00, 1944-01-28 00:00:00, 1944-01-29 00:00:00, 1944-01-30 00:00:00, 1944-01-31 00:00:00, 1944-02-01 00:00:00, 1944-02-02 00:00:00, 1944-02-03 00:00:00, 1944-02-04 00:00:00, 1944-02-05 00:00:00, 1944-02-06 00:00:00, 1944-02-07 00:00:00, 1944-02-08 00:00:00, 1944-02-09 00:00:00, 1944-02-10 00:00:00, 1944-02-11 00:00:00, 1944-02-12 00:00:00, 1944-02-13 00:00:00, 1944-02-14 00:00:00, 1944-02-15 00:00:00, 1944-02-16 00:00:00, 1944-02-17 00:00:00, 1944-02-18 00:00:00, 1944-02-19 00:00:00, 1944-02-20 00:00:00, 1944-02-21 00:00:00, 1944-02-22 00:00:00, 1944-02-23 00:00:00, 1944-02-24 00:00:00, 1944-02-25 00:00:00, 1944-02-26 00:00:00, 1944-02-27 00:00:00, 1944-02-28 00:00:00, 1944-02-29 00:00:00, 1944-03-01 00:00:00, 1944-03-02 00:00:00, 1944-03-03 00:00:00, 1944-03-04 00:00:00, 1944-03-05 00:00:00, 1944-03-06 00:00:00, 1944-03-07 00:00:00, 1944-03-08 00:00:00, 1944-03-09 00:00:00, 1944-03-10 00:00:00, 1944-03-11 00:00:00, 1944-03-12 00:00:00, 1944-03-13 00:00:00, 1944-03-14 00:00:00, 1944-03-15 00:00:00, 1944-03-16 00:00:00, 1944-03-17 00:00:00, 1944-03-18 00:00:00, 1944-03-19 00:00:00, 1944-03-20 00:00:00, 1944-03-21 00:00:00, 1944-03-22 00:00:00, 1944-03-23 00:00:00, 1944-03-24 00:00:00, 1944-03-25 00:00:00, 1944-03-26 00:00:00, 1944-03-27 00:00:00, 1944-03-28 00:00:00, 1944-03-29 00:00:00, 1944-03-30 00:00:00, 1944-03-31 00:00:00, 1944-04-01 00:00:00, 1944-04-02 00:00:00, 1944-04-03 00:00:00, 1944-04-04 00:00:00, 1944-04-05 00:00:00, 1944-04-06 00:00:00, 1944-04-07 00:00:00, 1944-04-08 00:00:00, 1944-04-09 00:00:00, ...]
#
# [25993 rows x 0 columns]

# %%
tmp['TMIN'] = tmin
tmp['TMAX'] = tmax

# %%
tmp.head()
# Out:
#             TMIN  TMAX
# 1944-01-01   NaN  22.2
# 1944-01-02   5.0   NaN
# 1944-01-03   3.9  23.9
# 1944-01-04   5.0  22.2
# 1944-01-05   6.1   NaN

# %%
tmp.plot()

# %%
tmp['TMIN'].plot()

# %%
tmp.TMIN.plot()

# %%
tmp['mean'] = (tmp['TMAX'] + tmp['TMIN'])/2.
tmp.head()
# Out:
#             TMIN  TMAX  mean
# 1944-01-01   NaN  22.2   NaN
# 1944-01-02   5.0   NaN   NaN
# 1944-01-03   3.9  23.9  13.9
# 1944-01-04   5.0  22.2  13.6
# 1944-01-05   6.1   NaN   NaN

# %%
tmp['Diff'] = tmp['TMAX'] - tmp['TMIN']
tmp.head()
# Out:
#             TMIN  TMAX  mean  Diff
# 1944-01-01   NaN  22.2   NaN   NaN
# 1944-01-02   5.0   NaN   NaN   NaN
# 1944-01-03   3.9  23.9  13.9  20.0
# 1944-01-04   5.0  22.2  13.6  17.2
# 1944-01-05   6.1   NaN   NaN   NaN

# %% [markdown]
# Find and plot all differences that are larger than 20

# %%
tmp.Diff[tmp.Diff > 20 ].plot(style='r*')

# %%
del tmp['Diff']
tmp.tail()
# Out:
#             TMIN  TMAX   mean
# 2015-02-25   NaN  28.6    NaN
# 2015-02-26  14.5  27.6  21.05
# 2015-02-27  11.1  27.6  19.35
# 2015-02-28  12.6  29.2  20.90
# 2015-03-01   NaN   NaN    NaN

# %%
tmp['1981-01':'1981-03'].plot()

# %% [markdown]
# Back to simple stuff. We can obtain statistical information over elements of the Data Frame. Default is column wise:

# %%
tmp.mean()
# Out:
# TMIN    18.530961
# TMAX    31.402131
# mean    25.000823
# dtype: float64

# %%
tmp.max()
# Out:
# TMIN    36.40
# TMAX    47.90
# mean    40.55
# dtype: float64

# %%
tmp.min()
# Out:
# TMIN    0.0
# TMAX    9.8
# mean    7.0
# dtype: float64

# %%
tmp.mean
# Out:
# <bound method DataFrame.mean of             TMIN  TMAX   mean
# 1944-01-01   NaN  22.2    NaN
# 1944-01-02   5.0   NaN    NaN
# 1944-01-03   3.9  23.9  13.90
# 1944-01-04   5.0  22.2  13.60
# 1944-01-05   6.1   NaN    NaN
# 1944-01-06   NaN  22.8    NaN
# 1944-01-07   5.6  22.2  13.90
# ...          ...   ...    ...
# 2015-02-23  16.6  28.6  22.60
# 2015-02-24  15.2  28.6  21.90
# 2015-02-25   NaN  28.6    NaN
# 2015-02-26  14.5  27.6  21.05
# 2015-02-27  11.1  27.6  19.35
# 2015-02-28  12.6  29.2  20.90
# 2015-03-01   NaN   NaN    NaN
#
# [25993 rows x 3 columns]>

# %%
tmp.mean(1)
# Out:
# 1944-01-01    22.20
# 1944-01-02     5.00
# 1944-01-03    13.90
# 1944-01-04    13.60
# 1944-01-05     6.10
# 1944-01-06    22.80
# 1944-01-07    13.90
#               ...
# 2015-02-23    22.60
# 2015-02-24    21.90
# 2015-02-25    28.60
# 2015-02-26    21.05
# 2015-02-27    19.35
# 2015-02-28    20.90
# 2015-03-01      NaN
# Freq: D, Length: 25993, dtype: float64

# %%
tmp.describe()
# Out:
#                TMIN          TMAX          mean
# count  14208.000000  15436.000000  12694.000000
# mean      18.530961     31.402131     25.000823
# std        7.808766      6.740111      7.020202
# min        0.000000      9.800000      7.000000
# 25%       11.400000     26.200000     18.800000
# 50%       19.500000     32.600000     26.500000
# 75%       25.600000     36.100000     30.700000
# max       36.400000     47.900000     40.550000

# %%
del tmp['mean']

# %%
tmp.corr()
# Out:
#           TMIN      TMAX
# TMIN  1.000000  0.882849
# TMAX  0.882849  1.000000

# %% [markdown]
# Find mean of all TMIN and TMAX temperatures larger than 20

# %%
# %whos
# Out:
# Variable   Type             Data/Info
# -------------------------------------
# ax         AxesSubplot      Axes(0.125,0.125;0.775x0.755)
# dd         DatetimeIndex    DatetimeIndex(['1944-01-0<...>, length=25993, freq='D')
# fig        Figure           Figure(432x288)
# np         module           <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module           <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt        module           <module 'matplotlib.pylab<...>s\\matplotlib\\pylab.py'>
# tmax       DataFrame                    Temp\nDate   <...>n[15436 rows x 1 columns]
# tmin       DataFrame                    Temp\nDate   <...>n[14208 rows x 1 columns]
# tmp        DataFrame                    TMIN  TMAX\n1<...>n[25993 rows x 2 columns]
# x          DataFrame                    Temp\nDate   <...>\n[7700 rows x 1 columns]
# y          DataFrame                    Temp\nDate   <...>n[15436 rows x 1 columns]
# z          DataFrame                    Temp\nDate   <...>n[15436 rows x 1 columns]

# %%
MIN20 = tmp.TMIN[tmp.TMIN >20]
MAX20 = tmp.TMAX[tmp.TMAX >20]

# %%
print(MAX20.mean(0))
print(MIN20.mean(0))
# Out:
# 32.23970406056378
# 25.63380384167647

# %% [markdown]
# Resampling
# Pandas provide easy way to resample data to different time frequency. Two main parameters for resampling is time period you resemple to and the method that you use. By default the method is mean. Following example calculates monthly ('M'):

# %%
tmp_mm = tmp.resample("M").mean()
tmp_mm['2000':].plot()

# %%
tmp_mm = tmp.resample("3M").apply(np.max)
tmp_mm['2000':].plot()

# %%
tmp_mm = tmp.resample("3M").apply([np.max, np.min])
tmp_mm['2000':].plot()

# %% [markdown]
# Seasonal means with resample
# Initially pandas was created for analysis of financial information and it thinks not in seasons, but in quarters. So we have to resample our data to quarters. We also need to make a shift from standard quarters, so they correspond with seasons. This is done by using 'Q-NOV' as a time frequency, indicating that year in our case ends in November:
# SBH What?

# %%
q_mean = tmp.resample('Q-NOV').mean()
q_mean
# Out:
#                  TMIN       TMAX
# 1944-02-29   7.802174  22.386486
# 1944-05-31  18.810909  36.321429
# 1944-08-31  26.178462  36.729825
# 1944-11-30  17.024528  32.702667
# 1945-02-28   6.944286  23.422414
# 1945-05-31  19.001695  36.496341
# 1945-08-31  26.761404  37.720290
# ...               ...        ...
# 2013-11-30  19.038636  31.909890
# 2014-02-28   8.851852  22.180000
# 2014-05-31  19.486585  34.459551
# 2014-08-31  27.475641  38.603261
# 2014-11-30  18.868605  32.735556
# 2015-02-28   9.123377  22.421348
# 2015-05-31        NaN        NaN
#
# [286 rows x 2 columns]

# %%
q_mean.plot()

# %%
# Plot winters
q_mean[q_mean.index.quarter==1].plot()

# %% [markdown]
# Multi-year monthly means with groupby
# First step will be to add another column to our DataFrame with month numbers:

# %%
tmp['mon'] = tmp.index.month
tmp
# Out:
#             TMIN  TMAX  mon
# 1944-01-01   NaN  22.2    1
# 1944-01-02   5.0   NaN    1
# 1944-01-03   3.9  23.9    1
# 1944-01-04   5.0  22.2    1
# 1944-01-05   6.1   NaN    1
# 1944-01-06   NaN  22.8    1
# 1944-01-07   5.6  22.2    1
# ...          ...   ...  ...
# 2015-02-23  16.6  28.6    2
# 2015-02-24  15.2  28.6    2
# 2015-02-25   NaN  28.6    2
# 2015-02-26  14.5  27.6    2
# 2015-02-27  11.1  27.6    2
# 2015-02-28  12.6  29.2    2
# 2015-03-01   NaN   NaN    3
#
# [25993 rows x 3 columns]

# %%
monmean = tmp['1950':'2013'].groupby('mon').aggregate(np.mean)
monmean.plot(kind='bar')

# %%
tmp.boxplot(column=['TMAX'], by='mon', figsize=(10,5))
tmp.boxplot(column=['TMIN'], by='mon', figsize=(10,5))

# %% [markdown]
# Exercise
# Define function that will find difference between maximum and minimum values of the resampled slice, and resample our tmp variable with this function.

# %%
tmp_mm_diff = tmp.resample("3M").apply(np.diff)
tmp_mm_diff
# Out:
# 1944-01-31    [[nan, -21.2], [nan, nan], [20.0, -22.9], [17....
# 1944-04-30    [[nan, nan], [nan, nan], [nan, nan], [13.9, -2...
# 1944-07-31    [[nan, -36.7], [nan, -35.0], [nan, -36.1], [19...
# 1944-10-31    [[nan, nan], [nan, nan], [8.9, -27.6], [nan, -...
# 1945-01-31    [[nan, -22.9], [21.1, -24.0], [nan, -20.1], [n...
# 1945-04-30    [[nan, nan], [nan, nan], [nan, nan], [nan, nan...
# 1945-07-31    [[18.4, -37.8], [nan, -36.1], [nan, -36.1], [1...
#                                     ...
# 2013-10-31    [[9.0, -26.9], [8.5, -28.0], [8.7, -28.1], [8....
# 2014-01-31    [[12.1, -19.5], [12.3, -17.6], [14.5, -17.1], ...
# 2014-04-30    [[nan, -19.1], [17.6, -22.4], [18.9, -25.8], [...
# 2014-07-31    [[18.6, -37.8], [15.5, -36.7], [nan, -36.7], [...
# 2014-10-31    [[9.6, -29.7], [nan, -27.3], [9.6, -28.6], [8....
# 2015-01-31    [[12.7, -18.3], [15.3, -20.1], [16.2, -20.2], ...
# 2015-04-30    [[17.3, -22.0], [13.4, -21.8], [nan, -21.8], [...
# Freq: 3M, Length: 286, dtype: object

# %% [markdown]
# Interpolate

# %%
del tmp['mon']

# %%
tmp['2005':'2006'].plot()

# %%
tmp['2005':'2006'].interpolate().plot()

# %%
ax = tmp['2005':'2006'].interpolate(method='cubic').plot()

# %% [markdown]
# Interactive data exploration

# %%
interpolated = tmp['1980':'2006'].interpolate(method='cubic')

# %%
interpolated['TMAX'].rolling(window=30).mean().plot()

# %%
from ipywidgets import interact

# %%
def kp(window=10):
    interpolated[['TMAX']].rolling(window=window).mean().plot(ylim=(10,50))

# %%
cc = interact(kp, window=(10,70,5))
