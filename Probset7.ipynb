# %% [markdown]
# Problem Set 7- Aaron McGarvey
# Explanation and introductory data importation for final project
#
#
# 1. Find and describe a relevant data set that you will actually use for your term paper. Describe what it is, how many points or what size it is, where it is from (the exact source), and what FORMAT it is
#
# My dataset is a time series of depth-to-water measurements in a critically overdrafted groundwater well in San Bernardino, California. The data is from the USGS "Groundwater Watch" program website, spans 26 years (1991-2017), and includes daily measurements for a total record count of 9,106. Measurements are depth-to-water measurements and are recorded in feet from land surface.
#
# Data avilable at https://groundwaterwatch.usgs.gov/DownloadDV2.asp?S=340615117170902&sc=06&sa=CA
#
# 2. From the dataset, tell me what variable(s) you hope to extract and analyze.
#
# For my purposes right now, the variable I'm looking at is the depth-to-water measurements in a single well. Further on, for my actual project, I intend to analyze datasets for multiple wells in a given groundwater basin.
#
# 3. Describe as much as you can what kind of analyses you intend to do (statistics, time series, image analysis, spatial plotting...)
#
# Doing a time series analysis to examine changes in the water table over time is the most obvious use for this data, but I'd like to go beyond that. For my immediate purposes, I think analyzing periodicity in a single well is the easiest place to start. The level of the water table fluctuates naturally with time, but it would be interesting to know what other factors (frequencies) conttribute to any periodicity present in the data.
#
# Later on, the incorporation of data from multiple wells could include some spatial analyses as well, like measuring the overall water table drawdown in an entire basin as a function of location, not time. I would like to create a spatial variable that could measure the expected drawdown in a separate monitoring well given a specific pumping rate in another well in that basin.
#
#
# 4. Write a code to read in the data. Describe to me how you chose the function you are using to read in your data. If you are successful, show me some properties of your data. Check what shape it is, display the first few rows of it, etc. Does it have headers or not.

# %%
import numpy as np

# %%
np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ec3812c98c3a> in <module>()
# ----> 1 np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
# ...

# %%
#removing introductory information in text file

np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9661213219b8> in <module>()
#       1 #removing introductory information in text file
#       2
# ----> 3 np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     983
#     984             # Convert each value according to its column and store
# ...

# %%
#converting txt file to a csv and trying again

np.loadtxt(fname='Raw Well Data USGS.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e832ce87765c> in <module>()
#       1 #converting txt file to a csv and trying again
#       2
# ----> 3 np.loadtxt(fname='Raw Well Data USGS.csv', delimiter=',')
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     983
#     984             # Convert each value according to its column and store
# ...

# %%
np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ec3812c98c3a> in <module>()
# ----> 1 np.loadtxt(fname='Raw Well Data USGS.txt', delimiter=',')
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# C:\Users\aaron\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
# ...

# %%
np.loadtxt(fname=Raw Well Data USGS.txt, dtype=string)
# Out:
#   File "<ipython-input-9-b0b1c0d3610f>", line 1
#     np.loadtxt(fname=Raw Well Data USGS.txt, dtype=string)
#                             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas #trying to import using pandas

# %%
data = pandas.read_csv('Raw_Well_Data_USGS.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-c2e87c653a66> in <module>()
# ----> 1 data = pandas.read_csv('Raw_Well_Data_USGS.csv')
#
# ...

# %%
data = pandas.read_csv('Raw_Well_Data_USGS.csv')

# %%
import matplotlib as plt

# %%
data
# Out:
#      USGS 340615117170902 72019 00001 10/24/1991     83.55 ----- - [A]
# 0     USGS 340615117170902 72019 00001 10/25/1991   ...
# 1     USGS 340615117170902 72019 00001 10/26/1991   ...
# 2     USGS 340615117170902 72019 00001 10/27/1991   ...
# 3     USGS 340615117170902 72019 00001 10/28/1991   ...
# 4     USGS 340615117170902 72019 00001 10/29/1991   ...
# 5     USGS 340615117170902 72019 00001 10/30/1991   ...
# 6     USGS 340615117170902 72019 00001 10/31/1991   ...
# 7     USGS 340615117170902 72019 00001 11/01/1991   ...
# 8     USGS 340615117170902 72019 00001 11/02/1991   ...
# 9     USGS 340615117170902 72019 00001 11/03/1991   ...
# 10    USGS 340615117170902 72019 00001 11/04/1991   ...
# 11    USGS 340615117170902 72019 00001 11/05/1991   ...
# 12    USGS 340615117170902 72019 00001 11/06/1991   ...
# 13    USGS 340615117170902 72019 00001 11/07/1991   ...
# 14    USGS 340615117170902 72019 00001 11/08/1991   ...
# ...

# %%
data.columns
# Out:
# Index(['USGS 340615117170902 72019 00001 10/24/1991     83.55 ----- - [A]'], dtype='object')

# %%
data1 = pandas.read_csv('Raw Well Data USGS.csv')

# %%
data1
# Out:
#       Unnamed: 0     Column1  Column2
# 0              1  10/24/1991    83.55
# 1              2  10/25/1991    83.85
# 2              3  10/26/1991    83.85
# 3              4  10/27/1991    83.55
# 4              5  10/28/1991    82.55
# 5              6  10/29/1991    82.35
# 6              7  10/30/1991    81.35
# 7              8  10/31/1991    82.33
# 8              9   11/1/1991    82.53
# 9             10   11/2/1991    82.40
# 10            11   11/3/1991    82.59
# 11            12   11/4/1991    84.18
# 12            13   11/5/1991    84.18
# 13            14   11/6/1991    83.06
# 14            15   11/7/1991    82.65
# 15            16   11/8/1991    82.24
# 16            17   11/9/1991    81.53
# 17            18  11/10/1991    80.71
# 18            19  11/11/1991    80.20
# 19            20  11/12/1991    80.18
# 20            21  11/13/1991    80.27
# 21            22  11/14/1991    80.16
# 22            23  11/15/1991    78.55
# 23            24  11/16/1991    77.92
# ...

# %%
data.columns
# Out:
# Index(['USGS 340615117170902 72019 00001 10/24/1991     83.55 ----- - [A]'], dtype='object')

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Column1', 'Column2'], dtype='object')

# %%
plt.plot.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-2b45395b5638> in <module>()
# ----> 1 plt.plot.data1
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot
image = matplotlib.pyplot.imshow(data1)
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-dfa127065134> in <module>()
#       1 import matplotlib.pyplot
# ----> 2 image = matplotlib.pyplot.imshow(data1)
#       3 matplotlib.pyplot.show()
#
# C:\Users\aaron\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# C:\Users\aaron\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
#Running out of time, will need to return to this

# %% [markdown]
# Explain to me in words what you intend to show with your paper. What question are you trying to answer, what do you need to compute or plot to get there, and what skills/techniques do you think you need to learn in order to get there?
#
# I am attempting to develop quantitative criteria to evaluate the feasability of inter-basin groundwater allocation rights exchanges. What does that mean? Imagine that groundwater pumping is capped in a particular basin due to overdraft, and water stakeholders (farmers, vineyards, other water users etc.) are given a yearly allocation of acre-ft of water they are allowed to extract. Given the size and scope of their businesses, some stakeholders will use their entire allocation and require more, while others will use less. Creating water markets, or the ability of stakeholders to trade these allocations between themselves on a digital water exchange, is an idea I am currently investigating along with several team members from the MSAG program.
#
# The relevant data analysis question here is on what criteria should the green light be given for these trades to take place? This is the question I am attempting to solve. Obviously there are a multitude of both quantitative and qualitative factors that go into the calculation of an overall "sustianable yield" of a groundwater basin. For purposes of this class, I wish to look at the quantitative elements. Using FloPy, my ultimate goal is to develop a binary criteria (yes/no, 0,1, positive/negative) for which water trading can take place. Often times, the decision to limit pumping in a particular basin is made by analyzing the results of a groundwater model. This is where FloPy's integration with MODFLOW proves useful. In a best case scenario, I will be able to use Python to automate inputs into MODFLOW and then extract outputs from MODFLOW back into Python to be incorporated into some sort of overarching algorithm.
#
# I will need to develop my general Python skills, as well as begin to try to understand the concept of algorithms, how they are created, how Python can help with this, etc.

# %%
plt.plot(data1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-987f1dc1720c> in <module>()
# ----> 1 plt.plot(data1)
#       2 plt.show()
#
# C:\Users\aaron\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\Users\aaron\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# ...

# %%
plt.plot(data1['Column2'])
plt.show()
